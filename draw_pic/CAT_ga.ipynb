# %%
import os
import argparse
import math
import glob
import random
import itertools
import datetime
import time
import sys
import warnings
import scipy.io
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.nn.init as init
from torch import Tensor

import torch.autograd as autograd 
from torch.autograd import Variable
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.backends import cudnn

import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torchvision.utils import save_image, make_grid
from torchvision.transforms import Compose, Resize, ToTensor

from torchsummary import summary

from PIL import Image
import matplotlib.pyplot as plt


from einops import rearrange, reduce, repeat
from einops.layers.torch import Rearrange, Reduce

from utils import GradCAM, show_cam_on_image

cudnn.benchmark = False
cudnn.deterministic = True


# hugging face
from transformers import AutoImageProcessor, ViTForImageClassification, ViTFeatureExtractor, ViTModel
from datasets import load_dataset

gpus = [8]
os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'
os.environ["CUDA_VISIBLE_DEVICES"] = ','.join(map(str, gpus))
result_path = '/home/songyonghao/Documents/Code/NICE/results/Conf/cat/ga/test1/' 
model_idx = 'cat_ga'

# %%
parser = argparse.ArgumentParser(description='Experiment Stimuli Recognition test with CLIP encoder')
# parser.add_argument('data', metavar='DIR', nargs='?', default='/home/songyonghao/Documents/Data/IE/stimuli',
#                     help='path to dataset (default: imagenet)')
parser.add_argument('--dnn', default='clip', type=str)
parser.add_argument('--epoch', default='200', type=int)
parser.add_argument('--num_sub', default=10, type=int,
                    help='number of subjects used in the experiments. ')
parser.add_argument('-batch_size', '--batch-size', default=1000, type=int,
                    metavar='N',
                    help='mini-batch size (default: 256), this is the total '
                         'batch size of all GPUs on the current node when '
                         'using Data Parallel or Distributed Data Parallel')
parser.add_argument('--seed', default=2023, type=int,
                    help='seed for initializing training. ')


def weights_init_normal(m):
    classname = m.__class__.__name__
    if classname.find('Conv2d') != -1:
        init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('Linear') != -1:
        init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find('BatchNorm') != -1:
        init.normal_(m.weight.data, 1.0, 0.02)
        init.constant_(m.bias.data, 0.0)


class PatchEmbedding(nn.Module):
    def __init__(self, emb_size=40):
        # self.patch_size = patch_size
        super().__init__()
        self.shallownet = nn.Sequential(
            nn.Conv2d(1, 40, (1, 25), (1, 1)),
            nn.AvgPool2d((1, 51), (1, 5)),
            nn.BatchNorm2d(40),
            nn.ELU(),
            nn.Conv2d(40, 40, (63, 1), (1, 1)),
            nn.BatchNorm2d(40),
            nn.ELU(),
            nn.Dropout(0.5),
        )

        self.projection = nn.Sequential(
            nn.Conv2d(40, emb_size, (1, 1), stride=(1, 1)),  # 5 is better than 1
            Rearrange('b e (h) (w) -> b (h w) e'),
        )

    def forward(self, x: Tensor) -> Tensor:
        b, _, _, _ = x.shape
        x = self.shallownet(x)
        x = self.projection(x)
        return x


class MultiHeadAttention(nn.Module):
    def __init__(self, emb_size, num_heads, dropout):
        super().__init__()
        self.emb_size = emb_size
        self.num_heads = num_heads
        self.keys = nn.Linear(emb_size, emb_size)
        self.queries = nn.Linear(emb_size, emb_size)
        self.values = nn.Linear(emb_size, emb_size)
        self.att_drop = nn.Dropout(dropout)
        self.projection = nn.Linear(emb_size, emb_size)

    def forward(self, x: Tensor, mask: Tensor = None) -> Tensor:
        queries = rearrange(self.queries(x), "b n (h d) -> b h n d", h=self.num_heads)
        keys = rearrange(self.keys(x), "b n (h d) -> b h n d", h=self.num_heads)
        values = rearrange(self.values(x), "b n (h d) -> b h n d", h=self.num_heads)
        energy = torch.einsum('bhqd, bhkd -> bhqk', queries, keys)  # batch, num_heads, query_len, key_len
        if mask is not None:
            fill_value = torch.finfo(torch.float32).min
            energy.mask_fill(~mask, fill_value)

        scaling = self.emb_size ** (1 / 2)
        att = F.softmax(energy / scaling, dim=-1)
        att = self.att_drop(att)
        out = torch.einsum('bhal, bhlv -> bhav ', att, values)
        out = rearrange(out, "b h n d -> b n (h d)")
        out = self.projection(out)
        return out


class ResidualAdd(nn.Module):
    def __init__(self, fn):
        super().__init__()
        self.fn = fn

    def forward(self, x, **kwargs):
        res = x
        x = self.fn(x, **kwargs)
        x += res
        return x


class FeedForwardBlock(nn.Sequential):
    def __init__(self, emb_size, expansion, drop_p):
        super().__init__(
            nn.Linear(emb_size, expansion * emb_size),
            nn.GELU(),
            nn.Dropout(drop_p),
            nn.Linear(expansion * emb_size, emb_size),
        )

class GELU(nn.Module):
    def forward(self, input: Tensor) -> Tensor:
        return input*0.5*(1.0+torch.erf(input/math.sqrt(2.0)))

class TransformerEncoderBlock(nn.Sequential):
    def __init__(self,
                 emb_size,
                 num_heads=10,
                 drop_p=0.5,
                 forward_expansion=4,
                 forward_drop_p=0.5):
        super().__init__(
            ResidualAdd(nn.Sequential(
                nn.LayerNorm(emb_size),
                MultiHeadAttention(emb_size, num_heads, drop_p),
                nn.Dropout(drop_p)
            )),
            ResidualAdd(nn.Sequential(
                nn.LayerNorm(emb_size),
                FeedForwardBlock(
                    emb_size, expansion=forward_expansion, drop_p=forward_drop_p),
                nn.Dropout(drop_p)
            )
            ))


class TransformerEncoder(nn.Sequential):
    def __init__(self, depth, emb_size):
        super().__init__(*[TransformerEncoderBlock(emb_size) for _ in range(depth)])


class FlattenHead(nn.Sequential):
    def __init__(self, emb_size, n_classes):
        super().__init__()
        # self.fc = nn.Sequential(
        #     nn.Linear(2440, 256),
        #     nn.ELU(),
        #     nn.Dropout(0.5),
        #     nn.Linear(256, 40),
        # )

    def forward(self, x):
        x = x.contiguous().view(x.size(0), -1)
        # cls_out = self.fc(x) 
        return x


class ClassificationHead(nn.Sequential):
    def __init__(self):
        super().__init__()
        self.fc = nn.Sequential(
            # nn.Linear(2440, 256),
            # nn.ELU(),
            # nn.Dropout(0.5),
            nn.Linear(256, 40),
        )

    def forward(self, x):
        # x = x.contiguous().view(x.size(0), -1)
        cls_out = self.fc(x) 
        return x, cls_out   

from torch_geometric.nn import GATConv
class EEG_GAT(nn.Module):
    def __init__(self, in_channels=250, out_channels=250):
        super(EEG_GAT, self).__init__()
        self.in_channels = in_channels
        self.out_channels = out_channels
        self.conv1 = GATConv(in_channels=in_channels, out_channels=out_channels, heads=1)
        # self.conv2 = GATConv(in_channels=out_channels, out_channels=out_channels, heads=1)

        self.num_channels = 63
        # Create a list of tuples representing all possible edges between channels
        self.edge_index_list = torch.Tensor([(i, j) for i in range(self.num_channels) for j in range(self.num_channels) if i != j]).cuda()
        # Convert the list of tuples to a tensor
        self.edge_index = torch.tensor(self.edge_index_list, dtype=torch.long).t().contiguous().cuda()

    def forward(self, x):

        batch_size, _, num_channels, num_features = x.size()
        
        # Reshape x to (batch_size*num_channels, num_features) to pass through GATConv
        x = x.view(batch_size*num_channels, num_features)

        # # num_channels = 63
        # # Create a list of tuples representing all possible edges between channels
        # edge_index_list = [(i, j) for i in range(num_channels) for j in range(num_channels) if i != j]
        # # Convert the list of tuples to a tensor
        # edge_index = torch.tensor(edge_index_list, dtype=torch.long).t().contiguous().cuda()

        
        # Reshape edge_index to include node indices from all channels in each batch sample
        # edge_index = edge_index.view(-1, num_channels) + torch.arange(batch_size*num_channels).unsqueeze(1).to(x.device) * num_channels
        
        # Pass x through GATConv layers and reshape back to (batch_size, num_channels, num_features)
        x = self.conv1(x, self.edge_index)
        # x = self.conv2(x, edge_index)
        x = x.view(batch_size, num_channels, -1)
        x = x.unsqueeze(1)
        
        return x


class Enc_eeg(nn.Sequential):
    def __init__(self, emb_size=40, depth=3, n_classes=4, **kwargs):
        super().__init__(
            ResidualAdd(
                nn.Sequential(
                    # nn.LayerNorm(250),
                    EEG_GAT(),
                    nn.Dropout(0.3),
                )
            ),
            PatchEmbedding(emb_size),
            # TransformerEncoder(depth, emb_size),
            FlattenHead(emb_size, n_classes)
        )

        
# class Enc_img(nn.Sequential):
#     def __init__(self, emb_size=40, depth=6, n_classes=4, **kwargs):
#         super().__init__(
#             PatchEmbedding(emb_size),
#             # TransformerEncoder(depth, emb_size),
#             ClassificationHead(emb_size, n_classes)
#         )

        
class Proj_eeg(nn.Sequential):
    def __init__(self, embedding_dim=1440, proj_dim=768, drop_proj=0.5):
        super().__init__(
            nn.Linear(embedding_dim, proj_dim),
            ResidualAdd(nn.Sequential(
                nn.GELU(),
                nn.Linear(proj_dim, proj_dim),
                nn.Dropout(drop_proj),
            )),
            nn.LayerNorm(proj_dim),
            # ClassificationHead()
        )


class Proj_img(nn.Sequential):
    def __init__(self, embedding_dim=768, proj_dim=768, drop_proj=0.3):
        super().__init__(
            nn.Linear(embedding_dim, proj_dim),
            ResidualAdd(nn.Sequential(
                nn.GELU(),
                nn.Linear(proj_dim, proj_dim),
                nn.Dropout(drop_proj),
            )),
            nn.LayerNorm(proj_dim),
            # ClassificationHead()
        )
    def forward(self, x):

        return x

# %%
train_data = []
train_label = []
eeg_data_path = '/home/songyonghao/Documents/Data/Things-EEG2/Preprocessed_data_250Hz/'
nSub = 10
train_data = np.load(eeg_data_path + '/sub-' + format(nSub, '02') + '/preprocessed_eeg_training.npy', allow_pickle=True)
train_data = train_data['preprocessed_eeg_data']
train_data = np.mean(train_data, axis=1)
train_data = np.expand_dims(train_data, axis=1)

data = train_data
print(np.shape(data))


# ! A crucial step for adaptation on Transformer
# reshape_transform  b 61 40 -> b 40 1 61
def reshape_transform(tensor):
    result = rearrange(tensor, 'b (h w) e -> b e (h) (w)', h=1)
    return result


device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
model = Enc_eeg()

# # used for cnn model without transformer
# model.load_state_dict(torch.load('./model/model_cnn.pth', map_location=device))
# target_layers = [model[0].projection]  # set the layer you want to visualize, you can use torchsummary here to find the layer index
# cam = GradCAM(model=model, target_layers=target_layers, use_cuda=False)

model.load_state_dict(torch.load('/home/songyonghao/Documents/Code/NICE/model/cat_ga/cat_gaEnc_eeg_sub%d.pth'%nSub, map_location=device))
target_layers = [model[0]]  # set the target layer 
cam = GradCAM(model=model, target_layers=target_layers, use_cuda=True)



# TODO: Class Activation Topography (proposed in the paper)
import mne
from matplotlib import mlab as mlab

easycapm1_montage = mne.channels.make_standard_montage('easycap-M1')
ch_name = ['Fp1', 'Fp2', 'AF7', 'AF3', 'AFz', 'AF4', 'AF8', 'F7', 'F5', 'F3',
			'F1', 'F2', 'F4', 'F6', 'F8', 'FT9', 'FT7', 'FC5', 'FC3', 'FC1', 
			'FCz', 'FC2', 'FC4', 'FC6', 'FT8', 'FT10', 'T7', 'C5', 'C3', 'C1',
			'Cz', 'C2', 'C4', 'C6', 'T8', 'TP9', 'TP7', 'CP5', 'CP3', 'CP1', 
			'CPz', 'CP2', 'CP4', 'CP6', 'TP8', 'TP10', 'P7', 'P5', 'P3', 'P1',
			'Pz', 'P2', 'P4', 'P6', 'P8', 'PO7', 'PO3', 'POz', 'PO4', 'PO8',
			'O1', 'Oz', 'O2']
info = mne.create_info(ch_names=ch_name, sfreq=250., ch_types='eeg')


all_cam = []
# this loop is used to obtain the cam of each trial/sample
for i in range(np.shape(data)[0]):
    test = torch.as_tensor(data[i:i+1, :, :, :], dtype=torch.float32)
    test = torch.autograd.Variable(test, requires_grad=True)

    grayscale_cam = cam(input_tensor=test)
    grayscale_cam = grayscale_cam[0, :]
    all_cam.append(grayscale_cam)
# Out:
# (16540, 1, 63, 250)
# category id: [29]
# the loss is tensor(1.1577, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [787]
# the loss is tensor(0.9329, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [756]
# the loss is tensor(0.9243, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [62]
# the loss is tensor(1.0390, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [734]
# the loss is tensor(0.9838, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [311]
# the loss is tensor(0.9442, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [278]
# the loss is tensor(1.0288, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [983]
# the loss is tensor(1.0105, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1167]
# the loss is tensor(0.8799, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [349]
# the loss is tensor(1.0874, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1404]
# the loss is tensor(0.8562, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [410]
# the loss is tensor(0.8996, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [125]
# the loss is tensor(1.2200, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1158]
# the loss is tensor(0.9801, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [325]
# the loss is tensor(1.0428, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [209]
# the loss is tensor(1.2729, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [79]
# the loss is tensor(1.0788, device='cuda:0', grad_fn=<AddBackward0>)
# /tmp/ipykernel_2932529/2002840096.py:180: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   self.edge_index = torch.tensor(self.edge_index_list, dtype=torch.long).t().contiguous().cuda()
# category id: [1012]
# the loss is tensor(1.1621, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [110]
# the loss is tensor(0.8567, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [22]
# the loss is tensor(0.8997, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [85]
# the loss is tensor(0.8524, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [481]
# the loss is tensor(0.8459, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1288]
# the loss is tensor(0.8346, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1325]
# the loss is tensor(0.9985, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [14]
# the loss is tensor(0.7452, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [888]
# the loss is tensor(1.0047, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [246]
# the loss is tensor(1.0220, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [135]
# the loss is tensor(0.9865, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1127]
# the loss is tensor(0.8956, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [125]
# the loss is tensor(1.0149, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1189]
# the loss is tensor(0.9309, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1081]
# the loss is tensor(0.9529, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [203]
# the loss is tensor(0.9298, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [181]
# the loss is tensor(0.8914, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [631]
# the loss is tensor(0.8520, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1435]
# the loss is tensor(1.0167, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1066]
# the loss is tensor(0.9075, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1116]
# the loss is tensor(0.9514, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [410]
# the loss is tensor(0.9167, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1158]
# the loss is tensor(1.0482, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1418]
# the loss is tensor(1.7675, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [663]
# the loss is tensor(0.8960, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1325]
# the loss is tensor(1.0892, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [469]
# the loss is tensor(0.9682, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [926]
# the loss is tensor(1.0579, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [431]
# the loss is tensor(0.8695, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1106]
# the loss is tensor(0.9549, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1337]
# the loss is tensor(0.8933, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [153]
# the loss is tensor(1.2254, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [294]
# the loss is tensor(1.0453, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1325]
# the loss is tensor(1.1381, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1386]
# the loss is tensor(1.1009, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [338]
# the loss is tensor(0.7832, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1298]
# the loss is tensor(0.9762, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [844]
# the loss is tensor(1.0502, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [79]
# the loss is tensor(0.8513, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1]
# the loss is tensor(0.8725, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1209]
# the loss is tensor(1.0227, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [618]
# the loss is tensor(1.3029, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [197]
# the loss is tensor(1.2033, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [604]
# the loss is tensor(0.9153, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [965]
# the loss is tensor(0.8559, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1337]
# the loss is tensor(0.9085, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1365]
# the loss is tensor(0.9973, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1094]
# the loss is tensor(0.9649, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [955]
# the loss is tensor(1.1298, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [999]
# the loss is tensor(0.9674, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [210]
# the loss is tensor(0.8461, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1253]
# the loss is tensor(1.0635, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [170]
# the loss is tensor(1.0629, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1405]
# the loss is tensor(1.0688, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [239]
# the loss is tensor(0.9859, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [275]
# the loss is tensor(0.9246, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [562]
# the loss is tensor(0.9581, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [924]
# the loss is tensor(1.2334, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [355]
# the loss is tensor(0.8727, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [334]
# the loss is tensor(0.8941, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [766]
# the loss is tensor(0.9446, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [10]
# the loss is tensor(0.9878, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [765]
# the loss is tensor(1.0743, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1374]
# the loss is tensor(0.8745, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1151]
# the loss is tensor(0.9723, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [463]
# the loss is tensor(1.4403, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [894]
# the loss is tensor(0.9962, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1288]
# the loss is tensor(1.1350, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1325]
# the loss is tensor(1.3082, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1316]
# the loss is tensor(0.9059, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [941]
# the loss is tensor(1.3445, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [706]
# the loss is tensor(1.3862, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [125]
# the loss is tensor(1.5710, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1143]
# the loss is tensor(0.9335, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1147]
# the loss is tensor(1.0163, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [358]
# the loss is tensor(1.0210, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [326]
# the loss is tensor(1.1126, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [918]
# the loss is tensor(1.1794, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [841]
# the loss is tensor(0.8316, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1380]
# the loss is tensor(0.9758, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1281]
# the loss is tensor(0.9823, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [964]
# the loss is tensor(1.0840, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [81]
# the loss is tensor(1.1786, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [81]
# the loss is tensor(0.8930, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [933]
# the loss is tensor(0.9521, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1262]
# the loss is tensor(1.2040, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [126]
# the loss is tensor(1.0035, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [128]
# the loss is tensor(1.2211, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1170]
# the loss is tensor(1.0227, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [88]
# the loss is tensor(1.0305, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [141]
# the loss is tensor(1.1719, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [545]
# the loss is tensor(0.8452, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [454]
# the loss is tensor(1.0234, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [125]
# the loss is tensor(1.1468, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [124]
# the loss is tensor(1.3256, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1285]
# the loss is tensor(1.1040, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [338]
# the loss is tensor(1.0764, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1222]
# the loss is tensor(0.9379, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [808]
# the loss is tensor(0.8976, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1165]
# the loss is tensor(1.0682, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [509]
# the loss is tensor(1.0787, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1119]
# the loss is tensor(0.9191, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [579]
# the loss is tensor(0.8883, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [45]
# the loss is tensor(0.8850, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1355]
# the loss is tensor(1.1691, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [481]
# the loss is tensor(1.0712, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [382]
# the loss is tensor(0.8697, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [307]
# the loss is tensor(0.9468, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [965]
# the loss is tensor(0.9141, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [885]
# the loss is tensor(1.1561, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1093]
# the loss is tensor(1.1205, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [286]
# the loss is tensor(1.2483, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [389]
# the loss is tensor(1.1558, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1365]
# the loss is tensor(1.4371, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1263]
# the loss is tensor(1.0433, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [325]
# the loss is tensor(1.3556, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [989]
# the loss is tensor(1.1511, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1069]
# the loss is tensor(1.1405, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1012]
# the loss is tensor(1.1073, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [598]
# the loss is tensor(0.8657, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [325]
# the loss is tensor(1.0360, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [285]
# the loss is tensor(1.2321, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1166]
# the loss is tensor(1.0919, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [103]
# the loss is tensor(1.2057, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [558]
# the loss is tensor(1.1161, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1263]
# the loss is tensor(0.9107, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [926]
# the loss is tensor(1.1556, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [7]
# the loss is tensor(1.0140, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [547]
# the loss is tensor(1.0480, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [814]
# the loss is tensor(1.1119, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [998]
# the loss is tensor(1.0050, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [955]
# the loss is tensor(0.9884, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1365]
# the loss is tensor(1.0112, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1325]
# the loss is tensor(0.9812, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [574]
# the loss is tensor(0.8131, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [85]
# the loss is tensor(1.2435, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [966]
# the loss is tensor(0.9686, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [707]
# the loss is tensor(0.8746, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1333]
# the loss is tensor(1.5056, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1271]
# the loss is tensor(1.0425, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1365]
# the loss is tensor(1.1151, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1151]
# the loss is tensor(0.7357, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1423]
# the loss is tensor(0.9656, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1276]
# the loss is tensor(0.9523, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1368]
# the loss is tensor(0.9467, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1294]
# the loss is tensor(0.8463, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [165]
# the loss is tensor(1.1628, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [81]
# the loss is tensor(1.0950, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [81]
# the loss is tensor(0.9290, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [242]
# the loss is tensor(1.0057, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1213]
# the loss is tensor(1.1788, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1248]
# the loss is tensor(0.9535, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1156]
# the loss is tensor(0.8929, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [124]
# the loss is tensor(1.0378, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [856]
# the loss is tensor(1.1163, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [762]
# the loss is tensor(0.9255, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1258]
# the loss is tensor(0.9618, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1428]
# the loss is tensor(1.0639, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [58]
# the loss is tensor(0.8797, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [124]
# the loss is tensor(1.1541, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [565]
# the loss is tensor(0.9317, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [724]
# the loss is tensor(0.9564, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [94]
# the loss is tensor(0.8704, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1088]
# the loss is tensor(1.0038, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1027]
# the loss is tensor(1.0344, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [802]
# the loss is tensor(1.1402, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [84]
# the loss is tensor(1.0781, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [324]
# the loss is tensor(1.1650, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [787]
# the loss is tensor(0.8363, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1250]
# the loss is tensor(0.8419, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1071]
# the loss is tensor(1.0418, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [654]
# the loss is tensor(0.8158, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [485]
# the loss is tensor(1.1491, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [925]
# the loss is tensor(1.1423, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1370]
# the loss is tensor(1.0653, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1222]
# the loss is tensor(1.1144, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [233]
# the loss is tensor(0.8743, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1329]
# the loss is tensor(1.1820, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [966]
# the loss is tensor(1.0337, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [191]
# the loss is tensor(0.9783, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1342]
# the loss is tensor(0.9076, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [324]
# the loss is tensor(1.2137, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [765]
# the loss is tensor(1.1847, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [822]
# the loss is tensor(1.0551, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [675]
# the loss is tensor(0.9455, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [395]
# the loss is tensor(0.9742, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [84]
# the loss is tensor(1.2317, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1119]
# the loss is tensor(1.0065, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [481]
# the loss is tensor(1.2647, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [924]
# the loss is tensor(1.2145, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [566]
# the loss is tensor(1.0872, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [63]
# the loss is tensor(0.8361, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [281]
# the loss is tensor(1.0973, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [14]
# the loss is tensor(0.8910, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [919]
# the loss is tensor(1.0769, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1325]
# the loss is tensor(1.1038, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [333]
# the loss is tensor(1.1202, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [182]
# the loss is tensor(1.0612, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1383]
# the loss is tensor(1.0116, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1094]
# the loss is tensor(0.8893, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [695]
# the loss is tensor(1.1136, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [121]
# the loss is tensor(1.0128, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [404]
# the loss is tensor(0.9546, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [367]
# the loss is tensor(1.0577, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [122]
# the loss is tensor(1.0672, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [635]
# the loss is tensor(1.1978, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [968]
# the loss is tensor(1.0648, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [925]
# the loss is tensor(0.9618, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [212]
# the loss is tensor(1.3704, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1050]
# the loss is tensor(0.9226, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [574]
# the loss is tensor(1.1794, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [373]
# the loss is tensor(1.1915, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [333]
# the loss is tensor(1.0711, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [965]
# the loss is tensor(1.0051, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [106]
# the loss is tensor(1.1290, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [793]
# the loss is tensor(1.0707, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1343]
# the loss is tensor(1.0767, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [913]
# the loss is tensor(0.9147, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1237]
# the loss is tensor(0.8676, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1439]
# the loss is tensor(0.9530, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [6]
# the loss is tensor(0.9859, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1365]
# the loss is tensor(1.0520, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [27]
# the loss is tensor(0.8860, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [730]
# the loss is tensor(0.7428, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1134]
# the loss is tensor(0.9259, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [165]
# the loss is tensor(1.1769, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [854]
# the loss is tensor(1.0406, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [378]
# the loss is tensor(0.8599, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1325]
# the loss is tensor(0.9853, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [285]
# the loss is tensor(1.1385, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [925]
# the loss is tensor(1.0330, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [325]
# the loss is tensor(0.9576, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [968]
# the loss is tensor(0.8909, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [482]
# the loss is tensor(0.9193, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [311]
# the loss is tensor(0.9894, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [805]
# the loss is tensor(1.0732, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [983]
# the loss is tensor(1.2896, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [88]
# the loss is tensor(0.9452, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1368]
# the loss is tensor(1.1532, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1092]
# the loss is tensor(0.9838, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [758]
# the loss is tensor(0.9539, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1086]
# the loss is tensor(1.3007, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1054]
# the loss is tensor(1.0538, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1267]
# the loss is tensor(0.7831, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1362]
# the loss is tensor(1.1601, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1125]
# the loss is tensor(1.0942, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [81]
# the loss is tensor(0.9154, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1339]
# the loss is tensor(0.8916, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [199]
# the loss is tensor(1.1132, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1094]
# the loss is tensor(0.8648, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [205]
# the loss is tensor(1.1516, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1174]
# the loss is tensor(1.0811, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [332]
# the loss is tensor(0.8710, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [119]
# the loss is tensor(0.9905, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [559]
# the loss is tensor(0.8726, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1118]
# the loss is tensor(1.3008, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [565]
# the loss is tensor(0.9923, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1288]
# the loss is tensor(1.2577, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [728]
# the loss is tensor(1.1340, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [95]
# the loss is tensor(1.0562, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [156]
# the loss is tensor(0.8250, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [110]
# the loss is tensor(1.1619, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1155]
# the loss is tensor(1.1498, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [2]
# the loss is tensor(1.0426, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1281]
# the loss is tensor(1.0898, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1166]
# the loss is tensor(1.0872, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1158]
# the loss is tensor(1.3216, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [326]
# the loss is tensor(1.1170, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [290]
# the loss is tensor(0.8465, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1165]
# the loss is tensor(0.9798, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [81]
# the loss is tensor(0.7973, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1226]
# the loss is tensor(1.0915, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [358]
# the loss is tensor(1.1856, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1087]
# the loss is tensor(0.7687, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1139]
# the loss is tensor(1.1383, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [141]
# the loss is tensor(1.1794, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [307]
# the loss is tensor(1.1206, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1398]
# the loss is tensor(1.0049, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [165]
# the loss is tensor(1.3849, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [139]
# the loss is tensor(0.8605, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [166]
# the loss is tensor(1.5376, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [285]
# the loss is tensor(1.1123, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [642]
# the loss is tensor(1.0884, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [565]
# the loss is tensor(0.8384, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1405]
# the loss is tensor(0.9836, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [715]
# the loss is tensor(0.8117, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1125]
# the loss is tensor(0.7843, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [81]
# the loss is tensor(0.9862, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [711]
# the loss is tensor(0.8421, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [675]
# the loss is tensor(0.8885, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [688]
# the loss is tensor(0.9867, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [998]
# the loss is tensor(1.2923, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [399]
# the loss is tensor(1.1861, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [328]
# the loss is tensor(1.4052, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1395]
# the loss is tensor(1.1361, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [928]
# the loss is tensor(1.1016, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [287]
# the loss is tensor(1.1161, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [293]
# the loss is tensor(1.3655, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [814]
# the loss is tensor(1.0127, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1161]
# the loss is tensor(0.9660, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1365]
# the loss is tensor(0.9434, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [85]
# the loss is tensor(0.9254, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [755]
# the loss is tensor(0.9697, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [422]
# the loss is tensor(1.1865, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [787]
# the loss is tensor(1.1339, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [925]
# the loss is tensor(1.1592, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1164]
# the loss is tensor(0.9093, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [334]
# the loss is tensor(0.8730, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [335]
# the loss is tensor(0.8051, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [141]
# the loss is tensor(1.1260, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [587]
# the loss is tensor(0.9573, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1341]
# the loss is tensor(1.0910, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [882]
# the loss is tensor(0.9343, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [271]
# the loss is tensor(1.0810, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [336]
# the loss is tensor(0.8496, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1436]
# the loss is tensor(0.8708, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1052]
# the loss is tensor(1.2240, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [206]
# the loss is tensor(0.8536, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1365]
# the loss is tensor(1.2533, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1158]
# the loss is tensor(1.0301, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [565]
# the loss is tensor(1.0083, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [191]
# the loss is tensor(1.3018, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [724]
# the loss is tensor(0.9261, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [648]
# the loss is tensor(0.9038, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1094]
# the loss is tensor(0.9994, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [924]
# the loss is tensor(1.4422, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [525]
# the loss is tensor(1.1283, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [48]
# the loss is tensor(0.9270, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1216]
# the loss is tensor(1.2171, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [121]
# the loss is tensor(1.0744, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [703]
# the loss is tensor(1.0147, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [449]
# the loss is tensor(0.9639, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1290]
# the loss is tensor(1.0706, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1355]
# the loss is tensor(1.0475, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [252]
# the loss is tensor(1.0854, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1057]
# the loss is tensor(1.1375, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [165]
# the loss is tensor(1.2423, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [287]
# the loss is tensor(1.0326, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1346]
# the loss is tensor(1.3014, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1262]
# the loss is tensor(0.7113, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [530]
# the loss is tensor(1.2537, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [734]
# the loss is tensor(0.9434, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [17]
# the loss is tensor(1.0735, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [749]
# the loss is tensor(0.9972, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [525]
# the loss is tensor(1.0973, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [150]
# the loss is tensor(0.9798, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1047]
# the loss is tensor(1.0678, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1155]
# the loss is tensor(1.0967, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [126]
# the loss is tensor(1.1744, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [158]
# the loss is tensor(1.2095, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [765]
# the loss is tensor(1.1633, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1365]
# the loss is tensor(1.1957, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1438]
# the loss is tensor(1.0770, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [347]
# the loss is tensor(0.8710, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1433]
# the loss is tensor(1.0741, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1115]
# the loss is tensor(1.0038, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [398]
# the loss is tensor(0.7947, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [286]
# the loss is tensor(0.9006, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1435]
# the loss is tensor(1.2284, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [728]
# the loss is tensor(1.0945, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [724]
# the loss is tensor(0.9612, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1278]
# the loss is tensor(0.8763, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [392]
# the loss is tensor(0.9860, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [125]
# the loss is tensor(0.9458, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [254]
# the loss is tensor(1.2238, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [205]
# the loss is tensor(1.0999, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1325]
# the loss is tensor(1.2899, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [94]
# the loss is tensor(0.9449, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [165]
# the loss is tensor(1.1493, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [125]
# the loss is tensor(1.2551, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [134]
# the loss is tensor(0.9679, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [334]
# the loss is tensor(1.2628, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [884]
# the loss is tensor(0.9318, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [294]
# the loss is tensor(0.8778, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [325]
# the loss is tensor(1.1106, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1290]
# the loss is tensor(1.1117, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [965]
# the loss is tensor(1.1410, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1162]
# the loss is tensor(1.1357, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1337]
# the loss is tensor(0.9728, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [81]
# the loss is tensor(0.9904, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [947]
# the loss is tensor(0.8696, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [325]
# the loss is tensor(1.0464, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [631]
# the loss is tensor(1.0116, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [141]
# the loss is tensor(1.0796, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [5]
# the loss is tensor(0.8638, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [101]
# the loss is tensor(1.0110, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [141]
# the loss is tensor(1.2706, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [318]
# the loss is tensor(1.1842, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1128]
# the loss is tensor(1.1526, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [958]
# the loss is tensor(1.1888, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [566]
# the loss is tensor(1.0415, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [987]
# the loss is tensor(0.9779, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [349]
# the loss is tensor(0.8416, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1378]
# the loss is tensor(0.9058, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1423]
# the loss is tensor(1.1156, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [641]
# the loss is tensor(1.0003, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1363]
# the loss is tensor(1.1564, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [725]
# the loss is tensor(1.0482, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1166]
# the loss is tensor(1.2000, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [306]
# the loss is tensor(0.9833, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1102]
# the loss is tensor(1.0040, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1152]
# the loss is tensor(1.0777, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [125]
# the loss is tensor(0.9827, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1370]
# the loss is tensor(1.0206, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1109]
# the loss is tensor(0.9661, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [130]
# the loss is tensor(1.1725, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [441]
# the loss is tensor(0.7475, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [147]
# the loss is tensor(0.8992, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [886]
# the loss is tensor(1.0513, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [153]
# the loss is tensor(0.9927, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [881]
# the loss is tensor(1.1023, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1405]
# the loss is tensor(0.9605, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [690]
# the loss is tensor(0.8176, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1174]
# the loss is tensor(0.9120, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [526]
# the loss is tensor(0.9425, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [401]
# the loss is tensor(0.8827, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1227]
# the loss is tensor(1.0253, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1222]
# the loss is tensor(1.1256, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [922]
# the loss is tensor(1.0457, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1405]
# the loss is tensor(1.0551, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1368]
# the loss is tensor(0.8967, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1395]
# the loss is tensor(1.1304, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [925]
# the loss is tensor(1.0658, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [198]
# the loss is tensor(1.2398, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [244]
# the loss is tensor(1.7356, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [395]
# the loss is tensor(0.9889, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [707]
# the loss is tensor(0.9276, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [253]
# the loss is tensor(1.4340, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [355]
# the loss is tensor(1.1238, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [278]
# the loss is tensor(1.3271, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [667]
# the loss is tensor(1.0452, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [355]
# the loss is tensor(1.1177, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1325]
# the loss is tensor(1.0389, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [925]
# the loss is tensor(1.0858, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [125]
# the loss is tensor(1.1965, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [816]
# the loss is tensor(0.9855, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [41]
# the loss is tensor(0.8899, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [524]
# the loss is tensor(1.0061, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [522]
# the loss is tensor(0.9288, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [157]
# the loss is tensor(1.4921, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [765]
# the loss is tensor(1.2343, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [94]
# the loss is tensor(0.8876, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1133]
# the loss is tensor(0.9215, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [517]
# the loss is tensor(1.1191, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1035]
# the loss is tensor(1.0035, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [725]
# the loss is tensor(1.0788, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1076]
# the loss is tensor(0.8477, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [410]
# the loss is tensor(0.9977, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1238]
# the loss is tensor(0.9886, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [988]
# the loss is tensor(0.9389, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [758]
# the loss is tensor(1.4024, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [766]
# the loss is tensor(1.0338, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [841]
# the loss is tensor(1.1181, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [930]
# the loss is tensor(0.8987, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [108]
# the loss is tensor(0.9357, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [410]
# the loss is tensor(0.9104, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1222]
# the loss is tensor(1.1257, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1182]
# the loss is tensor(1.0087, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [614]
# the loss is tensor(0.9651, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [485]
# the loss is tensor(1.1224, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [925]
# the loss is tensor(1.1437, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [735]
# the loss is tensor(1.0745, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [271]
# the loss is tensor(0.8056, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [448]
# the loss is tensor(1.0803, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [315]
# the loss is tensor(1.1409, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [125]
# the loss is tensor(1.1032, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [479]
# the loss is tensor(0.9983, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [875]
# the loss is tensor(1.1043, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1340]
# the loss is tensor(1.0457, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [970]
# the loss is tensor(0.7776, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [454]
# the loss is tensor(0.9636, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [380]
# the loss is tensor(1.0231, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [485]
# the loss is tensor(1.0716, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [126]
# the loss is tensor(1.3056, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [135]
# the loss is tensor(1.1973, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [363]
# the loss is tensor(0.8768, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [422]
# the loss is tensor(0.9204, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [565]
# the loss is tensor(0.9723, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [610]
# the loss is tensor(0.8727, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1324]
# the loss is tensor(1.2742, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1374]
# the loss is tensor(0.9136, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [328]
# the loss is tensor(0.8386, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [72]
# the loss is tensor(1.0770, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1325]
# the loss is tensor(1.0137, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [358]
# the loss is tensor(1.5677, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [165]
# the loss is tensor(1.3739, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [441]
# the loss is tensor(0.9926, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [325]
# the loss is tensor(1.1873, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [167]
# the loss is tensor(0.7377, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [349]
# the loss is tensor(0.9054, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [766]
# the loss is tensor(1.2773, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [204]
# the loss is tensor(0.9849, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [974]
# the loss is tensor(0.9074, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1054]
# the loss is tensor(0.8646, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [358]
# the loss is tensor(1.1388, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [206]
# the loss is tensor(0.9426, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1128]
# the loss is tensor(1.1204, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1427]
# the loss is tensor(1.0112, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1309]
# the loss is tensor(1.2568, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [711]
# the loss is tensor(0.9535, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [293]
# the loss is tensor(1.1463, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [591]
# the loss is tensor(1.1059, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [549]
# the loss is tensor(1.0450, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [802]
# the loss is tensor(0.9947, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [135]
# the loss is tensor(0.8035, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1299]
# the loss is tensor(0.8979, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [318]
# the loss is tensor(1.0326, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [996]
# the loss is tensor(0.9735, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [347]
# the loss is tensor(0.8739, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [485]
# the loss is tensor(1.1627, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [570]
# the loss is tensor(0.8277, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [525]
# the loss is tensor(1.1301, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [150]
# the loss is tensor(1.0782, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1069]
# the loss is tensor(0.9864, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [196]
# the loss is tensor(0.9353, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1405]
# the loss is tensor(0.9208, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1290]
# the loss is tensor(1.0400, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1398]
# the loss is tensor(0.8852, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1315]
# the loss is tensor(1.1260, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [925]
# the loss is tensor(1.0730, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [888]
# the loss is tensor(0.8840, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1348]
# the loss is tensor(0.9038, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1218]
# the loss is tensor(1.0958, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [485]
# the loss is tensor(1.0559, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [605]
# the loss is tensor(0.9762, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1153]
# the loss is tensor(0.8990, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [130]
# the loss is tensor(1.0969, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [347]
# the loss is tensor(1.3188, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [182]
# the loss is tensor(0.9971, device='cuda:0', grad_fn=<AddBackward0>)
# ...
# category id: [1085]
# the loss is tensor(1.1242, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [422]
# the loss is tensor(0.8837, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1427]
# the loss is tensor(1.0375, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [965]
# the loss is tensor(1.0172, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1079]
# the loss is tensor(1.0270, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [918]
# the loss is tensor(1.0362, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [134]
# the loss is tensor(1.0252, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [156]
# the loss is tensor(1.0870, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1339]
# the loss is tensor(1.0972, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [402]
# the loss is tensor(1.0977, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [366]
# the loss is tensor(0.9949, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [353]
# the loss is tensor(1.2529, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [205]
# the loss is tensor(0.9616, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1187]
# the loss is tensor(1.0680, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [347]
# the loss is tensor(1.0676, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1168]
# the loss is tensor(1.2147, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [389]
# the loss is tensor(0.9494, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [281]
# the loss is tensor(0.9722, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1435]
# the loss is tensor(0.9596, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [115]
# the loss is tensor(0.8674, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [627]
# the loss is tensor(0.9571, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [202]
# the loss is tensor(0.8838, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [485]
# the loss is tensor(0.9954, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [355]
# the loss is tensor(0.8596, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [319]
# the loss is tensor(0.9088, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [126]
# the loss is tensor(1.0292, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [158]
# the loss is tensor(1.3733, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [128]
# the loss is tensor(1.0790, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1395]
# the loss is tensor(1.1031, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [410]
# the loss is tensor(0.8842, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [191]
# the loss is tensor(1.0325, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [198]
# the loss is tensor(2.0668, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [778]
# the loss is tensor(0.9011, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [922]
# the loss is tensor(0.9168, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1210]
# the loss is tensor(0.9000, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1174]
# the loss is tensor(0.9355, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [27]
# the loss is tensor(1.0081, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [267]
# the loss is tensor(0.7951, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [525]
# the loss is tensor(1.3377, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [294]
# the loss is tensor(1.0963, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [685]
# the loss is tensor(0.9165, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [165]
# the loss is tensor(1.0686, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [138]
# the loss is tensor(0.9704, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [768]
# the loss is tensor(1.2223, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1079]
# the loss is tensor(0.9534, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [319]
# the loss is tensor(1.0340, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [325]
# the loss is tensor(1.0232, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1284]
# the loss is tensor(0.9099, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1439]
# the loss is tensor(1.2836, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1006]
# the loss is tensor(0.9053, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [281]
# the loss is tensor(1.0988, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1438]
# the loss is tensor(1.0335, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1062]
# the loss is tensor(1.0635, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1155]
# the loss is tensor(1.0927, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1374]
# the loss is tensor(0.8778, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1324]
# the loss is tensor(1.1337, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1147]
# the loss is tensor(0.8973, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [725]
# the loss is tensor(0.9641, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [602]
# the loss is tensor(1.0151, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1143]
# the loss is tensor(0.9948, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1365]
# the loss is tensor(1.2630, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [538]
# the loss is tensor(0.9011, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [166]
# the loss is tensor(1.0971, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [81]
# the loss is tensor(1.0207, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [631]
# the loss is tensor(0.9474, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [639]
# the loss is tensor(1.0901, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [482]
# the loss is tensor(0.9376, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1435]
# the loss is tensor(1.5267, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1393]
# the loss is tensor(1.0314, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [81]
# the loss is tensor(0.9942, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1365]
# the loss is tensor(1.0492, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [351]
# the loss is tensor(1.0633, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [96]
# the loss is tensor(1.2644, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [728]
# the loss is tensor(0.8040, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1324]
# the loss is tensor(1.2238, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [14]
# the loss is tensor(1.0624, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [497]
# the loss is tensor(0.9970, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1092]
# the loss is tensor(0.9513, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1298]
# the loss is tensor(0.8403, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [725]
# the loss is tensor(1.0622, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [29]
# the loss is tensor(1.0417, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1329]
# the loss is tensor(1.3846, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [598]
# the loss is tensor(0.9259, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [862]
# the loss is tensor(0.9738, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [956]
# the loss is tensor(0.9345, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [761]
# the loss is tensor(0.9879, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [22]
# the loss is tensor(0.9906, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [165]
# the loss is tensor(0.9597, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1229]
# the loss is tensor(0.9116, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [119]
# the loss is tensor(0.9315, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [294]
# the loss is tensor(1.1575, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1290]
# the loss is tensor(0.9321, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [151]
# the loss is tensor(0.9226, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [550]
# the loss is tensor(0.9932, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1189]
# the loss is tensor(0.8657, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [204]
# the loss is tensor(1.0241, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [922]
# the loss is tensor(0.9673, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [969]
# the loss is tensor(0.8399, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [410]
# the loss is tensor(0.8035, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [244]
# the loss is tensor(0.9953, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1132]
# the loss is tensor(1.1850, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [694]
# the loss is tensor(1.2345, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [596]
# the loss is tensor(0.9322, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1311]
# the loss is tensor(0.8331, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [203]
# the loss is tensor(1.1343, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1006]
# the loss is tensor(0.9706, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [715]
# the loss is tensor(1.0700, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [387]
# the loss is tensor(1.1017, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1281]
# the loss is tensor(1.0074, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [134]
# the loss is tensor(0.8606, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [324]
# the loss is tensor(0.8765, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1208]
# the loss is tensor(1.2899, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [427]
# the loss is tensor(0.9245, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [541]
# the loss is tensor(1.0162, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [155]
# the loss is tensor(0.8636, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1378]
# the loss is tensor(0.8966, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1262]
# the loss is tensor(1.0919, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1430]
# the loss is tensor(1.0715, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [623]
# the loss is tensor(1.0988, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1418]
# the loss is tensor(0.8821, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [734]
# the loss is tensor(1.0017, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [867]
# the loss is tensor(1.0266, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [494]
# the loss is tensor(1.0822, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [153]
# the loss is tensor(0.9193, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1039]
# the loss is tensor(0.8643, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [765]
# the loss is tensor(1.0310, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [524]
# the loss is tensor(1.1362, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1368]
# the loss is tensor(1.3827, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [765]
# the loss is tensor(0.9917, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [926]
# the loss is tensor(0.7757, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1288]
# the loss is tensor(0.9320, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [326]
# the loss is tensor(1.0097, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1125]
# the loss is tensor(0.9443, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1368]
# the loss is tensor(1.0450, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [108]
# the loss is tensor(1.3635, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [136]
# the loss is tensor(1.0510, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [159]
# the loss is tensor(0.9451, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1332]
# the loss is tensor(1.0737, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1035]
# the loss is tensor(1.0179, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [90]
# the loss is tensor(0.9696, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [966]
# the loss is tensor(0.9890, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [109]
# the loss is tensor(1.0944, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [365]
# the loss is tensor(1.0116, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [518]
# the loss is tensor(1.2616, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1382]
# the loss is tensor(1.1001, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [81]
# the loss is tensor(1.3781, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [162]
# the loss is tensor(1.2487, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [765]
# the loss is tensor(0.8639, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1368]
# the loss is tensor(0.8487, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1285]
# the loss is tensor(1.0708, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [39]
# the loss is tensor(0.9350, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [696]
# the loss is tensor(1.2581, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1326]
# the loss is tensor(1.0803, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [766]
# the loss is tensor(0.9715, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1125]
# the loss is tensor(0.9635, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1269]
# the loss is tensor(0.9538, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [768]
# the loss is tensor(0.8106, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1125]
# the loss is tensor(1.1972, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [654]
# the loss is tensor(0.8294, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1128]
# the loss is tensor(1.2518, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1118]
# the loss is tensor(1.1494, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [391]
# the loss is tensor(0.8995, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1033]
# the loss is tensor(1.1653, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [205]
# the loss is tensor(0.8392, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1139]
# the loss is tensor(1.0883, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1202]
# the loss is tensor(1.0736, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [605]
# the loss is tensor(0.9174, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [467]
# the loss is tensor(0.9285, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [136]
# the loss is tensor(0.9516, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1039]
# the loss is tensor(1.1094, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [121]
# the loss is tensor(1.0459, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [715]
# the loss is tensor(0.9617, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1038]
# the loss is tensor(1.0764, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1366]
# the loss is tensor(0.9088, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [463]
# the loss is tensor(0.9192, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [125]
# the loss is tensor(1.0943, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [249]
# the loss is tensor(0.9861, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [553]
# the loss is tensor(0.9549, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [179]
# the loss is tensor(0.8163, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [33]
# the loss is tensor(0.9417, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1365]
# the loss is tensor(1.0735, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [559]
# the loss is tensor(1.1043, device='cuda:0', grad_fn=<AddBackward0>)
# category id: [1209]
# the loss is tensor(1.2653, device='cuda:0', grad_fn=<AddBackward0>)

# %%
# the mean of all data
test_all_data = np.squeeze(np.mean(data, axis=0))
test_all_data = (test_all_data - np.mean(test_all_data)) / np.std(test_all_data)
# test_all_data = 2*(test_all_data - np.min(test_all_data)) / (np.max(test_all_data) - np.min(test_all_data)) - 1
mean_all_test = np.mean(test_all_data, axis=1)

# the mean of all cam
test_all_cam = np.mean(all_cam, axis=0)
test_all_cam = (test_all_cam - np.mean(test_all_cam)) / np.std(test_all_cam)
# test_all_cam = 2*(test_all_cam - np.min(test_all_cam)) / (np.max(test_all_cam) - np.min(test_all_cam)) - 1
mean_all_cam = np.mean(test_all_cam, axis=1)

# apply cam on the input data
# hyb_all = test_all_data * test_all_cam

hyb_all = np.einsum('b c h w, b h w -> b h w', data, all_cam)
hyb_all = np.mean(hyb_all, axis=0)

hyb_all = (hyb_all - np.mean(hyb_all)) / np.std(hyb_all)
# hyb_all = 2*(hyb_all - np.min(hyb_all)) / (np.max(hyb_all) - np.min(hyb_all)) - 1
mean_hyb_all = np.mean(hyb_all, axis=1)

evoked = mne.EvokedArray(test_all_data, info)
evoked.set_montage(easycapm1_montage)

fig, [ax1, ax2, ax3] = plt.subplots(nrows=3)

# print(mean_all_test)
plt.subplot(311)
im1, cn1 = mne.viz.plot_topomap(mean_all_test, evoked.info, show=False, axes=ax1, res=1200, vlim=(-2, 2))

plt.subplot(312)
im2, cn2 = mne.viz.plot_topomap(mean_all_cam, evoked.info, show=False, axes=ax2, res=1200, vlim=(-2, 2))

plt.subplot(313)
im3, cn3 = mne.viz.plot_topomap(mean_hyb_all, evoked.info, show=False, axes=ax3, res=1200, vlim=(-2, 2))

ax1.set_ylabel('Input', fontsize=12)
ax2.set_ylabel('Self-Att', fontsize=12)
ax3.set_ylabel('Graph-Att', fontsize=12)
ax1.set_title('Sub%d' % nSub, fontsize=12)

plt.colorbar(im1, ax=ax1)
plt.colorbar(im2, ax=ax2)
plt.colorbar(im3, ax=ax3)
plt.tight_layout()
plt.savefig('/home/songyonghao/Documents/Code/NICE/pic/cat_ga_sub%d.png' % nSub, dpi=600)
plt.savefig('/home/songyonghao/Documents/Code/NICE/pic/cat_ga_sub%d.svg' % nSub, dpi=600)

# %%
print(max(mean_all_test))
print(max(mean_all_cam))
print(max(mean_hyb_all))
# plt.savefig('/home/songyonghao/Documents/Code/NICE/pic/Conf/cat_sa.png', dpi=600)
# Out:
# 2.6168167303969376
# 1.8059523
# 2.9472829033079115
